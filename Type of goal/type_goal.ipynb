# %% [markdown]
# ## Répartition des buts de Ronaldo et Messi par type

# %% [markdown]
# * Ronaldo type goal

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données depuis le fichier CSV dans un DataFrame
data = pd.read_csv("../datsets/data.csv")

# Filtrer les données pour ne garder que les buts de Ronaldo
ronaldo_data = data[data["Player"] == "Cristiano Ronaldo"]

# Compter le nombre de buts par type de but
goals_by_type = ronaldo_data["Type"].value_counts()

# Créer le graphique en forme de cercle avec les pourcentages
plt.pie(goals_by_type.values, labels=goals_by_type.index, autopct='%1.1f%%')
plt.title("Répartition des buts de Ronaldo par type")
plt.show()

# %% [markdown]
# * Messi type goal

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données depuis le fichier CSV dans un DataFrame
data = pd.read_csv("../datsets/data.csv")

# Filtrer les données pour ne garder que les buts de Ronaldo
messi_data = data[data["Player"] == "Lionel Messi"]

# Compter le nombre de buts par type de but
goals_by_type = messi_data["Type"].value_counts()

# Créer le graphique en forme de cercle avec les pourcentages
plt.pie(goals_by_type.values, labels=goals_by_type.index, autopct='%1.1f%%')
plt.title("Répartition des buts de Messi par type")
plt.show()
